# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import re
import time
import random
import os

# %%
def get_wikipedia_content(topic):
    """
    Fetch content from Wikipedia on a specific topic
    """
    url = f"https://en.wikipedia.org/wiki/{topic.replace(' ', '_')}"
    response = requests.get(url)
    if response.status_code != 200:
        print(f"Failed to fetch {url}")
        return []
    
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Get all paragraphs from the main content
    paragraphs = soup.select('#mw-content-text p')
    
    # Extract and clean text
    cleaned_paragraphs = []
    for p in paragraphs:
        text = p.get_text()
        # Remove citations [1], [2], etc.
        text = re.sub(r'\[\d+\]', '', text)
        # Remove extra whitespace
        text = re.sub(r'\s+', ' ', text).strip()
        
        # Filter out short paragraphs, empty ones, or those that are too long
        word_count = len(text.split())
        if 100 <= word_count <= 120:
            cleaned_paragraphs.append({
                'text': text,
                'word_count': word_count,
                'source': url,
                'topic': topic
            })
    
    return cleaned_paragraphs

# %%
def get_science_health_nutrition_topics():
    """
    Return a list of topics related to science, health and nutrition
    """
    science_topics = [
        'Biology', 'Chemistry', 'Physics', 'Astronomy', 'Neuroscience',
        'Quantum_mechanics', 'Genetics', 'Microbiology', 'Cell_biology',
        'Ecology', 'Evolution', 'Climate_change', 'Biotechnology',
        'Artificial_intelligence', 'Machine_learning', 'Computer_science',
        'Immunology', 'Geology', 'Oceanography', 'Mathematics'
    ]
    
    health_topics = [
        'Medicine', 'Public_health', 'Epidemiology', 'Mental_health',
        'Physical_fitness', 'Disease', 'Cancer', 'Diabetes', 'Heart_disease',
        'Vaccine', 'Pandemic', 'Preventive_healthcare', 'Surgery',
        'Telemedicine', 'Healthcare', 'Medical_research', 'Exercise',
        'Sleep', 'Stress_management', 'Wellness'
    ]
    
    nutrition_topics = [
        'Nutrition', 'Diet_(nutrition)', 'Mediterranean_diet', 'Vitamin',
        'Mineral_(nutrient)', 'Protein', 'Carbohydrate', 'Fat', 'Dietary_fiber',
        'Antioxidant', 'Food_group', 'Calorie', 'Malnutrition', 'Metabolic_health',
        'Vegetarianism', 'Veganism', 'Whole_food', 'Gut_microbiome', 'Food_science',
        'Nutritional_supplement'
    ]
    
    # Also include subcategories and related topics
    extended_topics = [
        'Molecular_biology', 'Physiology', 'Anatomy', 'Pharmacology',
        'Cardiovascular_system', 'Immune_system', 'Digestive_system',
        'Endocrine_system', 'Metabolism', 'Nutrigenomics', 'Plant-based_diet',
        'Functional_food', 'Probiotics', 'Intermittent_fasting', 'Ketogenic_diet',
        'Micronutrient', 'Macronutrient', 'Food_pyramid_(nutrition)',
        'Nutritional_epidemiology', 'Biochemistry', 'Organic_chemistry'
    ]

    # Additional Science Topics
    additional_science_topics = [
        'Astrophysics', 'Cosmology', 'String_theory', 'Particle_physics', 'Nuclear_physics',
        'Thermodynamics', 'Fluid_dynamics', 'Relativity', 'Optics', 'Acoustics',
        'Materials_science', 'Nanotechnology', 'Robotics', 'Cryptography', 'Quantum_computing',
        'Systems_biology', 'Computational_biology', 'Bioinformatics', 'Genomics', 'Proteomics',
        'Developmental_biology', 'Marine_biology', 'Zoology', 'Botany', 'Mycology',
        'Paleontology', 'Archaeology', 'Anthropology', 'Seismology', 'Mineralogy',
        'Plate_tectonics', 'Volcanology', 'Meteorology', 'Atmospheric_science', 'Environmental_science',
        'Renewable_energy', 'Nuclear_energy', 'Data_science', 'Network_theory', 'Graph_theory',
        'Statistics', 'Linear_algebra', 'Calculus', 'Number_theory', 'Topology',
        'Chaos_theory', 'Complexity_theory', 'Cybernetics', 'Systems_theory', 'Information_theory'
    ]

    # Additional Health Topics
    additional_health_topics = [
        'Neurology', 'Cardiology', 'Oncology', 'Pediatrics', 'Geriatrics',
        'Orthopedics', 'Dermatology', 'Ophthalmology', 'Psychiatry', 'Psychology',
        'Obstetrics', 'Gynecology', 'Urology', 'Nephrology', 'Endocrinology',
        'Gastroenterology', 'Pulmonology', 'Rheumatology', 'Hematology', 'Infectious_disease',
        'Autoimmune_disease', 'Allergy', 'Medical_imaging', 'Laboratory_medicine', 'Pathology',
        'Emergency_medicine', 'Intensive_care', 'Palliative_care', 'Rehabilitation_medicine', 'Sports_medicine',
        'Occupational_health', 'Environmental_health', 'Global_health', 'Health_policy', 'Health_economics',
        'Health_informatics', 'Telehealth', 'Personalized_medicine', 'Pharmacogenomics', 'Gene_therapy',
        'Stem_cell_therapy', 'Organ_transplantation', 'Artificial_organs', 'Prosthetics', 'Biomedical_engineering',
        'Health_psychology', 'Cognitive_behavioral_therapy', 'Mindfulness', 'Health_education', 'Health_literacy'
    ]

    # Additional Nutrition Topics
    additional_nutrition_topics = [
        'Nutrition_psychology', 'Dietary_patterns', 'Blue_zone_diet', 'DASH_diet', 'Low-carbohydrate_diet',
        'Gluten-free_diet', 'Food_allergy', 'Food_intolerance', 'Celiac_disease', 'Nutritional_deficiency',
        'Vitamin_D', 'Omega-3_fatty_acid', 'Essential_amino_acid', 'Branched-chain_amino_acid', 'Phytonutrient',
        'Polyphenol', 'Flavonoid', 'Carotenoid', 'Isoflavone', 'Lycopene',
        'Resveratrol', 'Curcumin', 'Fermented_food', 'Prebiotic', 'Dietary_supplement',
        'Sports_nutrition', 'Hydration', 'Electrolyte', 'Glycemic_index', 'Glycemic_load',
        'Insulin_resistance', 'Metabolic_syndrome', 'Nutritional_therapy', 'Nutrition_during_pregnancy', 'Pediatric_nutrition',
        'Geriatric_nutrition', 'Enteral_nutrition', 'Parenteral_nutrition', 'Food_safety', 'Food_processing',
        'Culinary_medicine', 'Food_as_medicine', 'Traditional_dietary_practices', 'Cultural_food_practices', 'Sustainable_nutrition'
    ]

    # Additional Extended Topics
    additional_extended_topics = [
        'Epigenetics', 'Circadian_rhythm', 'Chronobiology', 'Human_microbiome', 'Neuroplasticity',
        'Psychoneuroimmunology', 'Behavioral_medicine', 'Biofeedback', 'Neurogenesis', 'Synaptic_plasticity',
        'Regenerative_medicine', 'Precision_medicine', 'Digital_health', 'Health_wearables', 'Brain-computer_interface',
        'Medical_nanotechnology', 'Health_applications_of_AI', 'Virtual_reality_in_healthcare', 'Computational_medicine', 'Systems_medicine',
        'Network_medicine', 'Exposome', 'Social_determinants_of_health', 'Planetary_health', 'One_Health',
        'Zoonotic_disease', 'Antimicrobial_resistance', 'Biosecurity', 'Health_resilience', 'Disaster_medicine',
        'Trauma_medicine', 'Addiction_medicine', 'Pain_management', 'Sleep_medicine', 'Autonomic_nervous_system',
        'Neuroendocrinology', 'Psychosomatic_medicine', 'Nutritional_genomics', 'Nutriepigenomics', 'Medicinal_chemistry',
        'Pharmaceutical_biotechnology', 'Drug_delivery_systems', 'Nanomedicine', 'Translational_research', 'Health_services_research'
    ]
    
    # Combine all topics
    all_topics = science_topics + health_topics + nutrition_topics + extended_topics
    all_additional_topics = additional_science_topics + additional_health_topics + additional_nutrition_topics + additional_extended_topics
    return all_additional_topics

# %%
def main():
    topics = get_science_health_nutrition_topics()
    all_paragraphs = []
    target_count = 500
    
    # Shuffle topics to get diverse content
    random.shuffle(topics)
    
    print(f"Starting to collect paragraphs from {len(topics)} topics...")
    
    for topic in topics:
        if len(all_paragraphs) >= target_count:
            break
            
        print(f"Fetching content for: {topic}")
        paragraphs = get_wikipedia_content(topic)
        print(f"Found {len(paragraphs)} suitable paragraphs (100-120 words)")
        
        all_paragraphs.extend(paragraphs)
        
        # Respect Wikipedia's servers by adding a delay
        time.sleep(2)
        
        # Status update
        print(f"Total paragraphs collected so far: {len(all_paragraphs)}/{target_count}")
    
    # Create dataset
    df = pd.DataFrame(all_paragraphs)
    
    filename = 'wikipedia_dataset.csv'
    file_exists = os.path.isfile(filename)
    
    if file_exists:
        # If file exists, append without writing the header
        print(f"Appending {len(df)} entries to existing file {filename}")
        df.to_csv(filename, mode='a', header=False, index=False)
    else:
        # If file doesn't exist, create it with header
        print(f"Creating new file {filename} with {len(df)} entries")
        df.to_csv(filename, index=False)
    
    # Show sample statistics
    print("\nWord count statistics:")
    print(f"Average: {df['word_count'].mean():.2f} words")
    print(f"Min: {df['word_count'].min()} words")
    print(f"Max: {df['word_count'].max()} words")
    
    # Distribution of topics
    print("\nTopic distribution:")
    topic_counts = df['topic'].value_counts()
    for topic, count in topic_counts.items():
        print(f"{topic}: {count} paragraphs")

# %%
if __name__ == "__main__":
    main()
# Out:
# Starting to collect paragraphs from 190 topics...
# Fetching content for: Nanotechnology
# Found 5 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 5/500
# Fetching content for: Food_safety
# Found 7 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 12/500
# Fetching content for: Intensive_care
# Found 2 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 14/500
# Fetching content for: Branched-chain_amino_acid
# Found 0 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 14/500
# Fetching content for: Dermatology
# Found 2 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 16/500
# Fetching content for: Medical_imaging
# Found 9 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 25/500
# Fetching content for: Pediatric_nutrition
# Failed to fetch https://en.wikipedia.org/wiki/Pediatric_nutrition
# Found 0 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 25/500
# Fetching content for: Traditional_dietary_practices
# Failed to fetch https://en.wikipedia.org/wiki/Traditional_dietary_practices
# Found 0 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 25/500
# Fetching content for: Ophthalmology
# Found 4 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 29/500
# Fetching content for: Genomics
# Found 6 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 35/500
# Fetching content for: Behavioral_medicine
# Found 3 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 38/500
# Fetching content for: Health_policy
# Found 4 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 42/500
# Fetching content for: Infectious_disease
# Found 8 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 50/500
# Fetching content for: Hematology
# Found 0 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 50/500
# Fetching content for: Telehealth
# Found 7 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 57/500
# Fetching content for: Allergy
# Found 4 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 61/500
# Fetching content for: Prebiotic
# Found 0 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 61/500
# Fetching content for: Personalized_medicine
# Found 8 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 69/500
# Fetching content for: Graph_theory
# Found 2 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 71/500
# Fetching content for: Psychosomatic_medicine
# Found 3 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 74/500
# Fetching content for: Obstetrics
# Found 2 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 76/500
# Fetching content for: Anthropology
# Found 12 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 88/500
# Fetching content for: Laboratory_medicine
# Found 2 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 90/500
# Fetching content for: Complexity_theory
# Found 0 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 90/500
# Fetching content for: Biosecurity
# Found 1 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 91/500
# Fetching content for: Geriatric_nutrition
# Failed to fetch https://en.wikipedia.org/wiki/Geriatric_nutrition
# Found 0 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 91/500
# Fetching content for: Dietary_patterns
# Failed to fetch https://en.wikipedia.org/wiki/Dietary_patterns
# Found 0 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 91/500
# Fetching content for: Nutritional_genomics
# Found 0 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 91/500
# Fetching content for: Gene_therapy
# Found 12 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 103/500
# Fetching content for: Global_health
# Found 7 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 110/500
# Fetching content for: Nuclear_energy
# Found 0 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 110/500
# Fetching content for: Rehabilitation_medicine
# Found 2 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 112/500
# Fetching content for: Translational_research
# Found 2 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 114/500
# Fetching content for: Trauma_medicine
# Found 1 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 115/500
# Fetching content for: Systems_medicine
# Found 0 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 115/500
# Fetching content for: Medicinal_chemistry
# Found 1 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 116/500
# Fetching content for: Cardiology
# Found 5 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 121/500
# Fetching content for: Proteomics
# Found 6 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 127/500
# Fetching content for: Artificial_organs
# Found 4 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 131/500
# Fetching content for: Omega-3_fatty_acid
# Found 7 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 138/500
# Fetching content for: Systems_theory
# Found 7 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 145/500
# Fetching content for: Enteral_nutrition
# Found 1 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 146/500
# Fetching content for: Glycemic_index
# Found 2 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 148/500
# Fetching content for: Psychoneuroimmunology
# Found 1 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 149/500
# Fetching content for: Nutritional_deficiency
# Found 13 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 162/500
# Fetching content for: Health_applications_of_AI
# Failed to fetch https://en.wikipedia.org/wiki/Health_applications_of_AI
# Found 0 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 162/500
# Fetching content for: Neuroplasticity
# Found 9 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 171/500
# Fetching content for: Psychology
# Found 26 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 197/500
# Fetching content for: Glycemic_load
# Found 2 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 199/500
# Fetching content for: Nephrology
# Found 5 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 204/500
# Fetching content for: Health_informatics
# Found 11 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 215/500
# Fetching content for: Computational_biology
# Found 3 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 218/500
# Fetching content for: Circadian_rhythm
# Found 9 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 227/500
# Fetching content for: Marine_biology
# Found 6 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 233/500
# Fetching content for: Orthopedics
# Found 3 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 236/500
# Fetching content for: Cognitive_behavioral_therapy
# Found 12 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 248/500
# Fetching content for: One_Health
# Found 3 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 251/500
# Fetching content for: Nanomedicine
# Found 5 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 256/500
# Fetching content for: Linear_algebra
# Found 3 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 259/500
# Fetching content for: Health_literacy
# Found 5 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 264/500
# Fetching content for: Geriatrics
# Found 3 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 267/500
# Fetching content for: Mycology
# Found 1 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 268/500
# Fetching content for: Quantum_computing
# Found 8 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 276/500
# Fetching content for: Autoimmune_disease
# Found 2 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 278/500
# Fetching content for: Culinary_medicine
# Failed to fetch https://en.wikipedia.org/wiki/Culinary_medicine
# Found 0 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 278/500
# Fetching content for: Curcumin
# Found 1 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 279/500
# Fetching content for: Systems_biology
# Found 3 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 282/500
# Fetching content for: Environmental_health
# Found 4 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 286/500
# Fetching content for: Atmospheric_science
# Found 4 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 290/500
# Fetching content for: Essential_amino_acid
# Found 7 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 297/500
# Fetching content for: Network_theory
# Found 2 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 299/500
# Fetching content for: Paleontology
# Found 4 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 303/500
# Fetching content for: Resveratrol
# Found 1 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 304/500
# Fetching content for: Particle_physics
# Found 5 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 309/500
# Fetching content for: Drug_delivery_systems
# Found 3 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 312/500
# Fetching content for: Food_intolerance
# Found 6 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 318/500
# Fetching content for: Digital_health
# Found 10 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 328/500
# Fetching content for: Health_services_research
# Found 2 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 330/500
# Fetching content for: Biomedical_engineering
# Found 5 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 335/500
# Fetching content for: Meteorology
# Found 5 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 340/500
# Fetching content for: Sports_nutrition
# Found 1 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 341/500
# Fetching content for: Food_as_medicine
# Failed to fetch https://en.wikipedia.org/wiki/Food_as_medicine
# Found 0 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 341/500
# Fetching content for: Insulin_resistance
# Found 5 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 346/500
# Fetching content for: Zoology
# Found 6 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 352/500
# Fetching content for: Cosmology
# Found 3 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 355/500
# Fetching content for: Occupational_health
# Found 11 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 366/500
# Fetching content for: Cultural_food_practices
# Failed to fetch https://en.wikipedia.org/wiki/Cultural_food_practices
# Found 0 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 366/500
# Fetching content for: Polyphenol
# Found 2 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 368/500
# Fetching content for: Precision_medicine
# Found 8 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 376/500
# Fetching content for: Food_allergy
# Found 7 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 383/500
# Fetching content for: Pain_management
# Found 7 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 390/500
# Fetching content for: Health_resilience
# Failed to fetch https://en.wikipedia.org/wiki/Health_resilience
# Found 0 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 390/500
# Fetching content for: Epigenetics
# Found 11 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 401/500
# Fetching content for: Fermented_food
# Found 1 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 402/500
# Fetching content for: Medical_nanotechnology
# Found 5 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 407/500
# Fetching content for: Sports_medicine
# Found 0 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 407/500
# Fetching content for: Nutrition_psychology
# Found 3 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 410/500
# Fetching content for: Pharmaceutical_biotechnology
# Failed to fetch https://en.wikipedia.org/wiki/Pharmaceutical_biotechnology
# Found 0 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 410/500
# Fetching content for: Palliative_care
# Found 2 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 412/500
# Fetching content for: Astrophysics
# Found 3 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 415/500
# Fetching content for: Endocrinology
# Found 1 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 416/500
# Fetching content for: Organ_transplantation
# Found 17 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 433/500
# Fetching content for: Materials_science
# Found 10 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 443/500
# Fetching content for: Sustainable_nutrition
# Failed to fetch https://en.wikipedia.org/wiki/Sustainable_nutrition
# Found 0 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 443/500
# Fetching content for: Biofeedback
# Found 5 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 448/500
# Fetching content for: String_theory
# Found 22 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 470/500
# Fetching content for: Autonomic_nervous_system
# Found 0 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 470/500
# Fetching content for: Environmental_science
# Found 2 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 472/500
# Fetching content for: Pediatrics
# Found 3 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 475/500
# Fetching content for: Calculus
# Found 5 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 480/500
# Fetching content for: Zoonotic_disease
# Found 3 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 483/500
# Fetching content for: Nutriepigenomics
# Found 3 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 486/500
# Fetching content for: Psychiatry
# Found 6 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 492/500
# Fetching content for: Optics
# Found 14 suitable paragraphs (100-120 words)
# Total paragraphs collected so far: 506/500
# Appending 506 entries to existing file wikipedia_dataset.csv
#
# Word count statistics:
# Average: 109.35 words
# Min: 100 words
# Max: 120 words
#
# Topic distribution:
# Psychology: 26 paragraphs
# String_theory: 22 paragraphs
# Organ_transplantation: 17 paragraphs
# Optics: 14 paragraphs
# Nutritional_deficiency: 13 paragraphs
# Cognitive_behavioral_therapy: 12 paragraphs
# Gene_therapy: 12 paragraphs
# Anthropology: 12 paragraphs
# Health_informatics: 11 paragraphs
# Epigenetics: 11 paragraphs
# Occupational_health: 11 paragraphs
# Materials_science: 10 paragraphs
# Digital_health: 10 paragraphs
# Neuroplasticity: 9 paragraphs
# Circadian_rhythm: 9 paragraphs
# Medical_imaging: 9 paragraphs
# Infectious_disease: 8 paragraphs
# Precision_medicine: 8 paragraphs
# Personalized_medicine: 8 paragraphs
# Quantum_computing: 8 paragraphs
# Telehealth: 7 paragraphs
# Omega-3_fatty_acid: 7 paragraphs
# Essential_amino_acid: 7 paragraphs
# Global_health: 7 paragraphs
# Food_safety: 7 paragraphs
# Food_allergy: 7 paragraphs
# Pain_management: 7 paragraphs
# Systems_theory: 7 paragraphs
# Food_intolerance: 6 paragraphs
# Psychiatry: 6 paragraphs
# Proteomics: 6 paragraphs
# Zoology: 6 paragraphs
# Genomics: 6 paragraphs
# Marine_biology: 6 paragraphs
# Particle_physics: 5 paragraphs
# Biomedical_engineering: 5 paragraphs
# Meteorology: 5 paragraphs
# Insulin_resistance: 5 paragraphs
# Calculus: 5 paragraphs
# Biofeedback: 5 paragraphs
# Nanomedicine: 5 paragraphs
# Medical_nanotechnology: 5 paragraphs
# Nanotechnology: 5 paragraphs
# Health_literacy: 5 paragraphs
# Nephrology: 5 paragraphs
# Cardiology: 5 paragraphs
# Ophthalmology: 4 paragraphs
# Health_policy: 4 paragraphs
# Artificial_organs: 4 paragraphs
# Environmental_health: 4 paragraphs
# Atmospheric_science: 4 paragraphs
# Paleontology: 4 paragraphs
# Allergy: 4 paragraphs
# Zoonotic_disease: 3 paragraphs
# Nutriepigenomics: 3 paragraphs
# Pediatrics: 3 paragraphs
# Behavioral_medicine: 3 paragraphs
# Astrophysics: 3 paragraphs
# Nutrition_psychology: 3 paragraphs
# Psychosomatic_medicine: 3 paragraphs
# Cosmology: 3 paragraphs
# One_Health: 3 paragraphs
# Orthopedics: 3 paragraphs
# Drug_delivery_systems: 3 paragraphs
# Systems_biology: 3 paragraphs
# Computational_biology: 3 paragraphs
# Linear_algebra: 3 paragraphs
# Geriatrics: 3 paragraphs
# Graph_theory: 2 paragraphs
# Obstetrics: 2 paragraphs
# Palliative_care: 2 paragraphs
# Environmental_science: 2 paragraphs
# Health_services_research: 2 paragraphs
# Network_theory: 2 paragraphs
# Dermatology: 2 paragraphs
# Laboratory_medicine: 2 paragraphs
# Autoimmune_disease: 2 paragraphs
# Polyphenol: 2 paragraphs
# Rehabilitation_medicine: 2 paragraphs
# Translational_research: 2 paragraphs
# Glycemic_index: 2 paragraphs
# Intensive_care: 2 paragraphs
# Glycemic_load: 2 paragraphs
# Mycology: 1 paragraphs
# Enteral_nutrition: 1 paragraphs
# Curcumin: 1 paragraphs
# Endocrinology: 1 paragraphs
# Psychoneuroimmunology: 1 paragraphs
# Fermented_food: 1 paragraphs
# Biosecurity: 1 paragraphs
# Resveratrol: 1 paragraphs
# Sports_nutrition: 1 paragraphs
# Medicinal_chemistry: 1 paragraphs
# Trauma_medicine: 1 paragraphs
